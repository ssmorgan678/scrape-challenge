# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = 'https://static.bc-edx.com/data/web/mars_facts/temperature.html'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
bs = soup(html, 'html.parser')

# %%
# Extract all rows of data
rows = bs.find_all('tr')
rows
# Out:
# [<tr>
#  <th>id</th>
#  <th>terrestrial_date</th>
#  <th>sol</th>
#  <th>ls</th>
#  <th>month</th>
#  <th>min_temp</th>
#  <th>pressure</th>
#  </tr>,
#  <tr class="data-row">
#  <td>2</td>
#  <td>2012-08-16</td>
#  <td>10</td>
#  <td>155</td>
#  <td>6</td>
#  <td>-75.0</td>
#  <td>739.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>13</td>
#  <td>2012-08-17</td>
#  <td>11</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>24</td>
#  <td>2012-08-18</td>
#  <td>12</td>
#  <td>156</td>
#  <td>6</td>
#  <td>-76.0</td>
#  <td>741.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>35</td>
#  <td>2012-08-19</td>
#  <td>13</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>732.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>46</td>
#  <td>2012-08-20</td>
#  <td>14</td>
#  <td>157</td>
#  <td>6</td>
#  <td>-74.0</td>
#  <td>740.0</td>
#  </tr>,
#  <tr class="data-row">
#  <td>57</td>
#  <td>2012-08-21</td>
#  <td>15</td>
# ...

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
table_data = []
rows = bs.find_all('tr')

# Loop through the scraped data to create a list of rows
for data in rows[1: ]:
    columns = data.find_all('td')
    columns = [col.text.strip() for col in columns]
    table_data.append(columns)

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
header_columns = ['id', 'terrestrial_date', 'sol', 'ls', 'month', 'min_temp', 'pressure']
table_df = pd.DataFrame(table_data, columns=header_columns)

# %%
# Confirm DataFrame was created successfully
table_df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
print(table_df.dtypes)
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
table_df = table_df.astype({"id": "int", "sol": "int", "ls": "int", "month": "int"})
table_df = table_df.astype({"min_temp": "float", "pressure": "float"})
table_df.terrestrial_date = pd.to_datetime(table_df.terrestrial_date, dayfirst=True)

table_df
# Out:
#         id terrestrial_date   sol   ls  month  min_temp  pressure
# 0        2       2012-08-16    10  155      6     -75.0     739.0
# 1       13       2012-08-17    11  156      6     -76.0     740.0
# 2       24       2012-08-18    12  156      6     -76.0     741.0
# 3       35       2012-08-19    13  157      6     -74.0     732.0
# 4       46       2012-08-20    14  157      6     -74.0     740.0
# ...    ...              ...   ...  ...    ...       ...       ...
# 1862  1889       2018-02-23  1973  133      5     -78.0     730.0
# 1863  1892       2018-02-24  1974  134      5     -77.0     729.0
# 1864  1894       2018-02-25  1975  134      5     -76.0     729.0
# 1865  1893       2018-02-26  1976  135      5     -77.0     728.0
# 1866  1895       2018-02-27  1977  135      5     -77.0     727.0
#
# [1867 rows x 7 columns]

# %%
# Confirm type changes were successful by examining data types again
print(table_df.dtypes)
# Out:
# id                           int32
# terrestrial_date    datetime64[ns]
# sol                          int32
# ls                           int32
# month                        int32
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?
months = table_df.month.nunique()  
print(f"There are {months} months on Mars.")
# Out:
# There are 12 months on Mars.

# %%
# 2. How many Martian days' worth of data are there?
total_days = table_df.sol.drop_duplicates().size
print(f"There are {total_days} Martian days' worth of data.")
# Out:
# There are 1867 Martian days' worth of data.

# %%
# 3. What is the average low temperature by month?
low_temp_month = table_df.groupby('month')['min_temp'].mean()

print(f"The average temperature of the first month is: {low_temp_month[1]}")
print(f"The average temperature of the second month is: {low_temp_month[2]}")
print(f"The average temperature of the third month is: {low_temp_month[3]}")
print(f"The average temperature of the fourth month is: {low_temp_month[4]}")
print(f"The average temperature of the fifth month is: {low_temp_month[5]}")
print(f"The average temperature of the sixth month is: {low_temp_month[6]}")
print(f"The average temperature of the seventh month is: {low_temp_month[7]}")
print(f"The average temperature of the eighth month is: {low_temp_month[8]}")
print(f"The average temperature of the ninth month is: {low_temp_month[9]}")
print(f"The average temperature of the tenth month is: {low_temp_month[10]}")
print(f"The average temperature of the eleventh month is: {low_temp_month[11]}")
print(f"The average temperature of the twelfth month is: {low_temp_month[12]}")
# Out:
# The average temperature of the first month is: -77.16091954022988
# The average temperature of the second month is: -79.93258426966293
# The average temperature of the third month is: -83.30729166666667
# The average temperature of the fourth month is: -82.74742268041237
# The average temperature of the fifth month is: -79.30872483221476
# The average temperature of the sixth month is: -75.29931972789116
# The average temperature of the seventh month is: -72.28169014084507
# The average temperature of the eighth month is: -68.38297872340425
# The average temperature of the ninth month is: -69.17164179104478
# The average temperature of the tenth month is: -71.98214285714286
# The average temperature of the eleventh month is: -71.98550724637681
# The average temperature of the twelfth month is: -74.45180722891567

# %%
# Plot the average temperature by month
low_temp_month.plot.bar(title="Average Temperature by Month", color="mediumpurple", figsize=(8,6))

plt.xticks(rotation=0)
plt.xlabel("Month")
plt.ylabel("Average Temp (Celsius)")
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location
cold_hot_months = table_df.groupby('month')['min_temp'].agg(['min', 'max'])
print(cold_hot_months)
# Out:
#         min   max
# month
# 1     -82.0 -62.0
# 2     -86.0 -76.0
# 3     -90.0 -77.0
# 4     -89.0 -77.0
# 5     -85.0 -74.0
# 6     -84.0 -71.0
# 7     -78.0 -65.0
# 8     -75.0 -63.0
# 9     -78.0 -63.0
# 10    -81.0 -66.0
# 11    -78.0 -67.0
# 12    -81.0 -70.0

# %%
# 4. Average pressure by Martian month
avg_pressure = table_df.groupby('month')['pressure'].mean()
print(avg_pressure)
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month

avg_pressure.plot.bar(title="Average Pressure by Month", color="darkmagenta", figsize=(8,6))

plt.xticks(rotation=0)                 
plt.xlabel("Month")
plt.ylabel("Average Pressure")
plt.show()

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?

min_earth_date = table_df['terrestrial_date'].min()
max_earth_date = table_df['terrestrial_date'].max()


days_per_sol = (max_earth_date - min_earth_date).days / (table_df['sol'].max() - table_df['sol'].min())

days_per_sol = days_per_sol.days / (table_df['sol'].max() - table_df['sol'].min())
    
per_martian_year = days_per_sol * 687

print("There are {per_martian_year} Earth days in a Martian year.")

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# The distance from peak to peak is roughly 1425-750, or 675 days. A year on Mars appears to be about 675 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV

table_df.to_csv('../Resources/table_df.csv', index=False)

# %%
browser.quit()
